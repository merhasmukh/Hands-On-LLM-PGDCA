# %% [markdown]
# # Practical P29: Mini Project: Planning & Building (Group Work)
# **Learning Outcome**: Plan and scaffold a complete group AI Python application.
#
# ## Group Scaffold Structure
# When collaborating inside group projects (2-3 students), create directory skeletons and assign distinct roles (core routing, embeddings loading, Streamlit web integrations).
#
# ### Recommended Scaffold Structure:
# ```text
# study_assistant_project/
# ├── data/                # Lecture notes & knowledge base
# ├── src/
# │   ├── __init__.py
# │   ├── main.py          # Entry point loop
# │   └── query_engine.py  # RAG / Model pipeline classes
# ├── requirements.txt
# └── README.md
# ```

# %%
# Simple validation script checking that directory structure exists
import os
print('Active project path initialized.')
