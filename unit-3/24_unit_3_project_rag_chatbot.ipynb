# %% [markdown]
# # Practical P24: Unit 3 Project: Domain Chatbot with RAG
# **Learning Outcome**: Build a working RAG-powered domain chatbot with source citations.
#
# ## Overview
# In this session, you will combine document search indexes and conversational memory to create a domain-expert chatbot script.

# %%
import os
from pathlib import Path

# Let's check files inside our dataset folder
data_path = Path('data')
for p in data_path.glob('*.txt'):
    print(f"Source File available: {p.name}")

# %% [markdown]
# ## Running the Project Assistant Script
# Execute [rag_chatbot.py](file:///Users/galaxyofai/Desktop/Github/Hands-On-LLM-PGDCA/unit-3/rag_chatbot.py) in the terminal to interact with the finished domain chatbot.
